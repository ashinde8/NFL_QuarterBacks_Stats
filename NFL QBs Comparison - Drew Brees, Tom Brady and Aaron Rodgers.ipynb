# %%
# Comparisons to be made
# LAST 10 Years

Drew Brees      
Tom Brady
Aaron Rodgers

# %%
from IPython.display import Image
Image(filename='DTA.jpg')

# %%
import pandas as pd
import seaborn as sns
import re
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
def brady_rodgers_brees(year1, year2):


    for i in range(year1,year2):
        yr_col = []
    # For Tom Brady vs Peyton Manning
    # As we are comparing 2 players i.e. length of QB list 
    # we have
        QBs = ['AaronRodgers','TomBrady','DrewBrees']
        
        yrs = str(i)
        file_name = yrs + '_NFL_Passing.csv'
        dataframe = pd.read_csv(file_name)
        dataframe.fillna(0, inplace=True)
            
        PlayerNames = []
    
        for pl in dataframe['Player']:
            pl = re.sub('[^A-Za-z0-9]+','',pl)
            PlayerNames.append(pl)
    
        dataframe['Player_Name'] = PlayerNames
        dataframe = dataframe.drop(dataframe.columns[0], axis=1)
        
        final_dataframe = dataframe[dataframe['Player_Name'].isin(QBs)]
    
        final_dataframe.reset_index(drop=True, inplace=True)
        rows_num = final_dataframe.shape[0]
    
        for j in range(rows_num):
            yr_col.append(i)
        
        final_dataframe['Yr'] = yr_col
        final_df = final_dataframe
 
        
        if i == year1:
            rivalry = final_df
        else:
            rivalry = rivalry.append(final_df)

     
    return rivalry

# %%
QB = brady_rodgers_brees(2010,2020)

# %%
QB.head()
# Out:
#     Tm Pos  Cmp  Att   Yds  TD Int Lng  Sk Yds.1 4QC GWD   Player_Name    Yr
# 0  NOR  QB  448  658  4620  33  22  80  25   185   4   5     DrewBrees  2010
# 1  NWE  QB  324  492  3900  36   4  79  25   175   2   3      TomBrady  2010
# 2  GNB  QB  312  475  3922  28  11  86  31   193   0   1  AaronRodgers  2010
# 0  NOR  QB  468  657  5476  46  14  79  24   158   3   4     DrewBrees  2011
# 1  NWE  QB  401  611  5235  39  12  99  32   173   1   2      TomBrady  2011

# %%
legacy = QB.groupby('Player_Name')

# %%
Tom_Brady = legacy.get_group('TomBrady')

# %%
Tom_Brady.reset_index(inplace=True)

# %%
Tom_Brady.dtypes
# Out:
# index           int64
# Tm             object
# Pos            object
# Cmp            object
# Att            object
# Yds            object
# TD             object
# Int            object
# Lng            object
# Sk             object
# Yds.1          object
# 4QC            object
# GWD            object
# Player_Name    object
# Yr              int64
# dtype: object

# %%
Tom_Brady.columns
# Out:
# Index(['index', 'Tm', 'Pos', 'Cmp', 'Att', 'Yds', 'TD', 'Int', 'Lng', 'Sk',
#        'Yds.1', '4QC', 'GWD', 'Player_Name', 'Yr'],
#       dtype='object')

# %%
for i in Tom_Brady[['Cmp', 'Att', 'Yds', 'TD', 'Int', 'Lng', 'Sk',
       'Yds.1', '4QC', 'GWD']]:
    Tom_Brady[i] = Tom_Brady[i].astype(int)
    print(Tom_Brady[i].dtype)
# Out:
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32

# %%
Tom_Brady.drop(['index'], axis=1, inplace=True)

# %%
Tom_Brady
# Out:
#     Tm Pos  Cmp  Att   Yds  TD  Int  Lng  Sk  Yds.1  4QC  GWD Player_Name  \
# 0  NWE  QB  324  492  3900  36    4   79  25    175    2    3    TomBrady
# 1  NWE  QB  401  611  5235  39   12   99  32    173    1    2    TomBrady
# 2  NWE  QB  401  637  4827  34    8   83  27    182    1    2    TomBrady
# 3  NWE  QB  380  628  4343  25   11   81  40    256    5    5    TomBrady
# 4  NWE  QB  373  582  4109  33    9   69  21    134    2    2    TomBrady
# 5  NWE  QB  402  624  4770  36    7   76  38    225    2    2    TomBrady
# 6  NWE  QB  291  432  3554  28    2   79  15     87    1    1    TomBrady
# 7  NWE  QB  385  581  4577  32    8   64  35    201    2    2    TomBrady
# 8  NWE  QB  375  570  4355  29   11   63  21    147    1    2    TomBrady
# 9  NWE  QB  373  613  4057  24    8   59  27    185    1    1    TomBrady
#
#      Yr
# 0  2010
# 1  2011
# 2  2012
# 3  2013
# 4  2014
# 5  2015
# 6  2016
# 7  2017
# 8  2018
# 9  2019

# %%
AaronRodgers = legacy.get_group('AaronRodgers')

# %%
AaronRodgers.reset_index(inplace=True)

# %%
for j in AaronRodgers[['Cmp', 'Att', 'Yds', 'TD', 'Int', 'Lng', 'Sk',
       'Yds.1', '4QC', 'GWD']]:
    AaronRodgers[j] = AaronRodgers[j].astype(int)
    print(AaronRodgers[j].dtype)
# Out:
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32

# %%
AaronRodgers.drop(['index'],axis=1, inplace=True)

# %%
AaronRodgers
# Out:
#     Tm Pos  Cmp  Att   Yds  TD  Int  Lng  Sk  Yds.1  4QC  GWD   Player_Name  \
# 0  GNB  QB  312  475  3922  28   11   86  31    193    0    1  AaronRodgers
# 1  GNB  QB  343  502  4643  45    6   93  36    219    0    1  AaronRodgers
# 2  GNB  QB  371  552  4295  39    8   73  51    293    2    3  AaronRodgers
# 3  GNB  QB  193  290  2536  17    6   83  21    117    1    1  AaronRodgers
# 4  GNB  QB  341  520  4381  38    5   80  28    174    1    1  AaronRodgers
# 5  GNB  QB  347  572  3821  31    8   65  46    314    2    2  AaronRodgers
# 6  GNB  QB  401  610  4428  40    7   60  35    246    0    2  AaronRodgers
# 7  GNB  qb  154  238  1675  16    6   72  22    168    2    2  AaronRodgers
# 8  GNB  QB  372  597  4442  25    2   75  49    353    3    3  AaronRodgers
# 9  GNB  QB  353  569  4002  26    4   74  36    284    2    3  AaronRodgers
#
#      Yr
# 0  2010
# 1  2011
# 2  2012
# 3  2013
# 4  2014
# 5  2015
# 6  2016
# 7  2017
# 8  2018
# 9  2019

# %%
DrewBrees = legacy.get_group('DrewBrees')

# %%
DrewBrees.reset_index(inplace=True)

# %%
for k in DrewBrees[['Cmp', 'Att', 'Yds', 'TD', 'Int', 'Lng', 'Sk',
       'Yds.1', '4QC', 'GWD']]:
    DrewBrees[k] = DrewBrees[k].astype(int)
    print(DrewBrees[k].dtype)
# Out:
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32
# int32

# %%
DrewBrees.drop(['index'], axis=1, inplace=True)

# %%
DrewBrees
# Out:
#     Tm Pos  Cmp  Att   Yds  TD  Int  Lng  Sk  Yds.1  4QC  GWD Player_Name  \
# 0  NOR  QB  448  658  4620  33   22   80  25    185    4    5   DrewBrees
# 1  NOR  QB  468  657  5476  46   14   79  24    158    3    4   DrewBrees
# 2  NOR  QB  422  670  5177  43   19   80  26    190    1    2   DrewBrees
# 3  NOR  QB  446  650  5162  39   12   76  37    244    2    2   DrewBrees
# 4  NOR  QB  456  659  4952  33   17   69  29    186    2    2   DrewBrees
# 5  NOR  QB  428  627  4870  32   11   80  31    235    1    2   DrewBrees
# 6  NOR  QB  471  673  5208  37   15   98  27    184    2    4   DrewBrees
# 7  NOR  QB  386  536  4334  23    8   54  20    145    2    2   DrewBrees
# 8  NOR  QB  364  489  3992  32    5   72  17    121    6    7   DrewBrees
# 9  NOR  QB  281  378  2979  27    4   61  12     89    1    2   DrewBrees
#
#      Yr
# 0  2010
# 1  2011
# 2  2012
# 3  2013
# 4  2014
# 5  2015
# 6  2016
# 7  2017
# 8  2018
# 9  2019

# %%
data = {'Tom Brady':Tom_Brady['TD'],"Aaron Rodgers":AaronRodgers['TD'],"Drew Brees":DrewBrees['TD']}
animated_df = pd.DataFrame(data)

# %%
animated_df.dtypes
# Out:
# Tom Brady        int32
# Aaron Rodgers    int32
# Drew Brees       int32
# dtype: object

# %%
for i in animated_df.columns:
    animated_df[i] = animated_df[i].astype(int)
    print(animated_df[i].dtype)
# Out:
# int32
# int32
# int32

# %%
cum_sum_df = animated_df[['Tom Brady', 'Aaron Rodgers', 'Drew Brees']].cumsum(axis=0)
cum_sum_df['years']= DrewBrees['Yr']
cum_sum_df.set_index("years", inplace = True)

# %%
cum_sum_df
# Out:
#        Tom Brady  Aaron Rodgers  Drew Brees
# years
# 2010          36             28          33
# 2011          75             73          79
# 2012         109            112         122
# 2013         134            129         161
# 2014         167            167         194
# 2015         203            198         226
# 2016         231            238         263
# 2017         263            254         286
# 2018         292            279         318
# 2019         316            305         345

# %%
import bar_chart_race as bcr
bcr.bar_chart_race(df=cum_sum_df, filename = None, period_length = 1000, figsize = (6,6), title = 'Tom Brady v/s Aaron Rodgers v/s Drew Brees Touchdowns from 2010-2019')
# Out:
# <video width="908" height="864" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
Tom_Brady.head()
# Out:
#     Tm Pos  Cmp  Att   Yds  TD  Int  Lng  Sk  Yds.1  4QC  GWD Player_Name  \
# 0  NWE  QB  324  492  3900  36    4   79  25    175    2    3    TomBrady
# 1  NWE  QB  401  611  5235  39   12   99  32    173    1    2    TomBrady
# 2  NWE  QB  401  637  4827  34    8   83  27    182    1    2    TomBrady
# 3  NWE  QB  380  628  4343  25   11   81  40    256    5    5    TomBrady
# 4  NWE  QB  373  582  4109  33    9   69  21    134    2    2    TomBrady
#
#      Yr
# 0  2010
# 1  2011
# 2  2012
# 3  2013
# 4  2014

# %%
AaronRodgers.head()
# Out:
#     Tm Pos  Cmp  Att   Yds  TD  Int  Lng  Sk  Yds.1  4QC  GWD   Player_Name  \
# 0  GNB  QB  312  475  3922  28   11   86  31    193    0    1  AaronRodgers
# 1  GNB  QB  343  502  4643  45    6   93  36    219    0    1  AaronRodgers
# 2  GNB  QB  371  552  4295  39    8   73  51    293    2    3  AaronRodgers
# 3  GNB  QB  193  290  2536  17    6   83  21    117    1    1  AaronRodgers
# 4  GNB  QB  341  520  4381  38    5   80  28    174    1    1  AaronRodgers
#
#      Yr
# 0  2010
# 1  2011
# 2  2012
# 3  2013
# 4  2014

# %% [markdown]
# # Matplotlib

# %% [markdown]
# # No of times Tom Brady, Aaron Rodgers and Drew Brees got Sacked from the year 2010-2019

# %%
plt.plot(Tom_Brady['Yr'], Tom_Brady['Sk'], 'ro', linestyle = 'solid', linewidth=2, markersize=12, label = 'Tom Brady')
plt.plot(AaronRodgers['Yr'], AaronRodgers['Sk'], 'bo--', linestyle = 'dashed', linewidth=2, markersize=12, label = 'Aaron Rodgers')
plt.plot(DrewBrees['Yr'], DrewBrees['Sk'], 'go', linestyle = 'dotted', linewidth=2, markersize=12, label = 'Drew Brees')

plt.xlabel('Years')
plt.ylabel('Sacks')
plt.legend(loc="upper left")
fig = plt.gcf()
plt.xticks(Tom_Brady['Yr'])
fig.set_size_inches(27, 20)
plt.savefig('tbardb_sacks2.png', dpi=100)
plt.title("No of times Tom Brady, Aaron Rodgers and Drew Brees got Sacked from 2010-2019")
# Out:
# Text(0.5, 1, 'No of times Tom Brady, Aaron Rodgers and Drew Brees got Sacked from 2010-2019')

# %% [markdown]
# # Tom Brady v/s Drew Brees v/s Aaron Rodgers Passes Attempted Comparisons from 2010-2019

# %%
labels = Tom_Brady['Yr']
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, Tom_Brady['Att'], width, label='Tom Brady')
rects2 = ax.bar(x + width/2, DrewBrees['Att'], width, label='Drew Brees')
rects3 = ax.bar(x - width/8, AaronRodgers['Att'], width, label='Aaron Rodgers')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Years')
ax.set_title('Tom Brady v/s Drew Brees v/s Aaron Rodgers Passes Attempted Comparisons from 2010-2019')
ax.set_xticks(x)
fig = plt.gcf()
fig.set_size_inches(19, 13)
plt.savefig('tbardb_passes.png', dpi=100)
ax.set_xticklabels(labels)
ax.legend()
plt.show()
